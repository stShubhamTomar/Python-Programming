# %%
file=open("g:/5may.txt","w")
file.write("this is python")
file.write(str(2023))
file.flush()
import time
d=time.ctime()
file.write(d)
file.close()

# %%
file=open("g:/5may.txt","w")
file.write("this is python\n")
file.write(str(2023))
file.write("\n")
file.flush()
import time
d=time.ctime()
file.write(d)
file.close()

# %%
file=open("g:/5may.txt","a")
file.write("\nthis is india")
file.close()

# %%
file=open("g:/5may.txt","x")
file.write("this is india")
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 file=open("g:/5may.txt","x")
#       2 file.write("this is india")
#       3 file.close()
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'g:/5may.txt'

# %%
file=open("g:/5may.txt","w")
file.write("मैं बाजार जाऊँगा।")
file.write("\n")
file.write("ਮੈਂ ਬਾਜ਼ਾਰ ਜਾਵਾਂਗਾ।")
file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[18], line 2
#       1 file=open("g:/5may.txt","w")
# ----> 2 file.write("मैं बाजार जाऊँगा।")
#       3 file.write("\n")
#       4 file.write("ਮੈਂ ਬਾਜ਼ਾਰ ਜਾਵਾਂਗਾ।")
#
# File ~\anaconda3\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 0-2: character maps to <undefined>

# %%
file=open("g:/5may.txt","w",encoding="utf")
file.write("मैं बाजार जाऊँगा।")
file.write("\n")
file.write("ਮੈਂ ਬਾਜ਼ਾਰ ਜਾਵਾਂਗਾ।")
file.close()

# %%
file=open("g:/images/sachin2.jpg","r")
s=file.read()
print(s)
file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[20], line 2
#       1 file=open("g:/images/sachin2.jpg","r")
# ----> 2 s=file.read()
#       3 print(s)
#       4 file.close()
#
# File ~\anaconda3\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 287: character maps to <undefined>

# %%
file=open("g:/5may.txt","r")
data=file.read()
print(type(data))
file.close()
# Out:
# <class 'str'>

# %%
file=open("g:/5may.txt","rb")
data=file.read()
print(type(data),data)
file.close()
# Out:
# <class 'bytes'> b'hi\r\nhello\r\n'

# %%
file=open("g:/images/sachin2.jpg","rb")
data=file.read()
print(data)
file.close()

file=open("ss.jpg","wb")
file.write(data)
file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xe1\x00"Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x01\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x00\x00\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x02\x01\x01\x02\x02\x02\x02\x02\x02\x02\x02\x03\x05\x03\x03\x03\x03\x03\x06\x04\x04\x03\x05\x07\x06\x07\x07\x07\x06\x07\x07\x08\t\x0b\t\x08\x08\n\x08\x07\x07\n\r\n\n\x0b\x0c\x0c\x0c\x0c\x07\t\x0e\x0f\r\x0c\x0e\x0b\x0c\x0c\x0c\xff\xdb\x00C"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01
# ...

# %%
file=open("g:/5may.txt","r+") #read then write
s=file.read()
print(s)
file.write("bye")
file.close()
# Out:
# hi
# hello

# %%
file=open("g:/5may.txt","w+") #write,seek,read
file.write("bye")
file.seek(0)
s=file.read()
print(s)
file.close()
# Out:
# bye

# %% [markdown]
# # Filel Modes
# - r or rt
# - w or wt
# - a
# - x
# - rb
# - wb
# - r+
# - w+
# - a+
# - etc.

# %%
#with block
with open("g:/5may.txt","r") as file:
    print(file.read())
    file.seek(0)
    print(file.read())
print("bye")
print(file.read())
# Out:
# hi
# hi
# bye
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 7
#       5     print(file.read())
#       6 print("bye")
# ----> 7 print(file.read())
#
# ValueError: I/O operation on closed file.
